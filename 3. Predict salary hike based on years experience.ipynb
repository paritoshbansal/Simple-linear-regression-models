# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Create a simple linear regression model to build a prediction model for Salary Hike.

# %%
data=pd.read_csv("C:/Users/parit/Downloads/Salary_Data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
y=data["Salary"].values.reshape(-1,1)
x=data["YearsExperience"].values.reshape(-1,1)

# %% [markdown]
# ## Expolatory Data Analysis

# %%
sns.displot(x=data["Salary"],data=data)

# %%
sns.displot(x=data["YearsExperience"],data=data)

# %%
sns.scatterplot(x=data["Salary"],y=data["YearsExperience"],data=data)
# Out:
# <Axes: xlabel='Salary', ylabel='YearsExperience'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# ## checking null values

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# ## coorelation

# %%
sns.heatmap(data.corr(),vmin=-1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Linear regression model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression()

# %%
model=lin.fit(x_train,y_train)
print("training completed")
# Out:
# training completed

# %%
model.score(x_train,y_train)
print("score of training data=",model.score(x_train,y_train))
# Out:
# score of training data= 0.9630949350768394

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,model.predict(x_test))
print("r2_score of testing data=",r2_score(y_test,model.predict(x_test)))
# Out:
# r2_score of testing data= 0.6796306090871282

# %%
plt.scatter(x,y,color="b")
plt.plot(x,model.predict(x),color="r")
